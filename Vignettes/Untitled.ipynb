# %%
# Here is an explanation

# %%
import copernicusmarine                 # to download data from copernicus
import xarray as xr                     # working with netcdfs
import geopandas as gpd                 # working with shapefiles
import READ_EDAB_Utilities_py as reupy  # READ_EDAB functions
import matplotlib.pyplot as plt         # plotting
# %matplotlib inline

# %%
glorys = copernicusmarine.open_dataset(dataset_id="cmems_mod_glo_phy_my_0.083deg_P1D-m")
glorys
# Out:
# Fetching catalog: 100%|██████████████████████████████████████████████████████████████████| 3/3 [00:26<00:00,  8.69s/it]
# INFO - 2024-08-19T18:51:28Z - Dataset version was not specified, the latest one was selected: "202311"
# INFO - 2024-08-19T18:51:28Z - Dataset part was not specified, the first one was selected: "default"
# INFO - 2024-08-19T18:51:35Z - Service was not specified, the default one was selected: "arco-geo-series"
# username:
#   lgruenburg1
# password:
#   ········
# <xarray.Dataset>
# Dimensions:    (depth: 50, latitude: 2041, longitude: 4320, time: 10408)
# Coordinates:
#   * depth      (depth) float32 0.494 1.541 2.646 ... 5.275e+03 5.728e+03
#   * latitude   (latitude) float32 -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float32 -180.0 -179.9 -179.8 ... 179.8 179.8 179.9
#   * time       (time) datetime64[ns] 1993-01-01 1993-01-02 ... 2021-06-30
# Data variables:
#     bottomT    (time, latitude, longitude) float32 ...
# ...

# %% [markdown]
# This dataset is really big!  We can subset to the time and place that we are interested in

# %%
#subset glorys
glorys_subset = glorys.sel(
